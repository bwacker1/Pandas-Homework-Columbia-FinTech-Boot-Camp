# %% [markdown]
#  #  A Whale off the Port(folio)
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500.

# %%
# Importing libraries
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
# 1. whale_returns.csv
# 2. algo_returns.csv
# 3. sp500_history.csv

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_returns_csv = Path("Resources/whale_returns.csv")

whale_returns_df = pd.read_csv(whale_returns_csv, 
                               index_col='Date', parse_dates=True, infer_datetime_format=True)

# Sorting by index
whale_returns_df.sort_index(ascending=True,inplace=True)

# Printing sample
whale_returns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Counting nulls
whale_returns_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Dropping nulls
whale_returns_df.dropna(inplace=True)

# Recounting nulls
whale_returns_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns_csv = Path("Resources/algo_returns.csv")
algo_returns_df = pd.read_csv(algo_returns_csv, 
                               index_col='Date', parse_dates=True, infer_datetime_format=True)

# Sorting by index
algo_returns_df.sort_index(ascending=True,inplace=True)

# Printing sample
algo_returns_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Counting nulls
algo_returns_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Dropping nulls
algo_returns_df.dropna(inplace=True)

# Recounting nulls
algo_returns_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P500 Historic Closing Prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 closing prices
sp500_history_csv = Path("Resources/sp500_history.csv")

sp500_history_df = pd.read_csv(sp500_history_csv, 
                               index_col='Date', parse_dates=True, infer_datetime_format=True)

# Sorting by index
sp500_history_df.sort_index(ascending=True,inplace=True)

# Printing sample
sp500_history_df.head()
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
# Checking data type
sp500_history_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fixing data types

# Removing dollar sign 
sp500_history_df['Close'] = sp500_history_df['Close'].str.replace('$','')

# Converting to float
sp500_float = sp500_history_df['Close'].astype('float')

# Confirming data type conversion
print(sp500_float.dtypes)

# Converting data from series to dataframe
sp500_float_frame = sp500_float.to_frame()

# Printing sample
sp500_float_frame.head()
# Out:
# float64
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93

# %%
# Calculating daily returns
sp500_daily_returns = sp500_float_frame.pct_change()

# Confirming change
sp500_daily_returns.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
# Dropping nulls
sp500_daily_returns.dropna(inplace=True)

# %%
# Renaming "Close" column
sp500_daily_returns.columns = ['S&P 500']

# Confirming change
sp500_daily_returns.head()
# Out:
#              S&P 500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Concatenating all DataFrames into a single DataFrame
all_returns_df = pd.concat([whale_returns_df,algo_returns_df,sp500_daily_returns], axis='columns', join='inner')

# Sorting by index
all_returns_df.sort_index(ascending=True, inplace=True)

# Confirming successful concatenation
all_returns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# 2015-03-06 -0.011460 -0.014174
# 2015-03-09  0.001303  0.003944

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance
#
# Calculate and Plot the daily returns and cumulative returns.

# %%
# Plotting daily returns
all_returns_df.plot(title='Daily Returns', figsize=(20,10))

# %%
# Ploting cumulative returns
((all_returns_df + 1).cumprod() - 1).plot(title='Cumulative Returns', figsize=(20,10))

# %% [markdown]
# ---

# %% [markdown]
# ## Risk
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %%
# Box plotting to visually show risk
all_returns_df.boxplot(figsize=(20,10))

# %%
# Daily Standard Deviations

# Calculating the standard deviations for each portfolio and assigning to new dataframe
std_df = all_returns_df.std().to_frame()

# Naming Standard Deviation column
std_df.columns = ['Std. Dev.']

# Printing standard deviations for each portfolio
std_df
# Out:
#                              Std. Dev.
# SOROS FUND MANAGEMENT LLC     0.007895
# PAULSON & CO.INC.             0.007023
# TIGER GLOBAL MANAGEMENT LLC   0.010894
# BERKSHIRE HATHAWAY INC        0.012919
# Algo 1                        0.007620
# Algo 2                        0.008342
# S&P 500                       0.008554

# %%
# Determining which portfolios are riskier than the S&P 500
for index in std_df.index:
    if std_df['Std. Dev.'][index] > std_df.iloc[6,0]:
        print(f'{index} is riskier.')
    elif std_df['Std. Dev.'][index] < std_df.iloc[6,0]:
        print(f'{index} is safer.')
    else:
        print('')
# Out:
# SOROS FUND MANAGEMENT LLC is safer.
# PAULSON & CO.INC.  is safer.
# TIGER GLOBAL MANAGEMENT LLC is riskier.
# BERKSHIRE HATHAWAY INC is riskier.
# Algo 1 is safer.
# Algo 2 is safer.

# %%
# Calculating the annualized standard deviation (252 trading days) and assigning to new series
volatility = all_returns_df.std() * np.sqrt(252)

# Printing annualized standard deviation
volatility
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# S&P 500                        0.135786
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&P 500 using a 21 day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 2. Calculate and plot a 60 day Beta for Berkshire Hathaway Inc compared to the S&P 500

# %%
# Calculating the rolling standard deviations for the S&P 500 using a 21 day window
rolling_std = all_returns_df.rolling(window=21).std()

# Dropping nulls
rolling_std.dropna(inplace=True)

# Printing sample
rolling_std.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-31                   0.005764            0.004641
# 2015-04-01                   0.005744            0.004467
# 2015-04-02                   0.005749            0.004502
# 2015-04-06                   0.005792            0.004492
# 2015-04-07                   0.005452            0.004385
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-31                     0.006731                0.007108  0.007866
# 2015-04-01                     0.006750                0.007005  0.007886
# 2015-04-02                     0.006739                0.006958  0.007601
# 2015-04-06                     0.006786                0.006884  0.007648
# 2015-04-07                     0.006486                0.006193  0.007531
#
#               Algo 2   S&P 500
# Date
# 2015-03-31  0.006867  0.009105
# 2015-04-01  0.006894  0.009095
# 2015-04-02  0.006955  0.009114
# 2015-04-06  0.007028  0.009246
# 2015-04-07  0.006530  0.008707

# %%
# Plotting the rolling standard deviation
rolling_std.plot(title='Rolling 21-Day Std. Dev.', figsize=(20,10))

# %%
# Calculating standard deviation correlation between all portfolios and the S&P 500
rolling_std.corr(method='pearson')
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.664590
# PAULSON & CO.INC.                             0.664590            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.451969            0.407927
# BERKSHIRE HATHAWAY INC                        0.859187            0.631215
# Algo 1                                        0.721356            0.585584
# Algo 2                                        0.872922            0.688595
# S&P 500                                       0.911914            0.597760
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.451969
# PAULSON & CO.INC.                               0.407927
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.413311
# Algo 1                                          0.265667
# Algo 2                                          0.359691
# S&P 500                                         0.414108
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.859187  0.721356  0.872922
# PAULSON & CO.INC.                          0.631215  0.585584  0.688595
# TIGER GLOBAL MANAGEMENT LLC                0.413311  0.265667  0.359691
# BERKSHIRE HATHAWAY INC                     1.000000  0.794022  0.824877
# Algo 1                                     0.794022  1.000000  0.760948
# Algo 2                                     0.824877  0.760948  1.000000
# S&P 500                                    0.812766  0.699671  0.901190
#
#                               S&P 500
# SOROS FUND MANAGEMENT LLC    0.911914
# PAULSON & CO.INC.            0.597760
# TIGER GLOBAL MANAGEMENT LLC  0.414108
# BERKSHIRE HATHAWAY INC       0.812766
# Algo 1                       0.699671
# Algo 2                       0.901190
# S&P 500                      1.000000

# %%
# Calculating correlation between all portfolios and the S&P 500
all_returns_df.corr(method='pearson')
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P 500                                       0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# Algo 2                                          0.507414
# S&P 500                                         0.623946
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.754360  0.321211  0.826873
# PAULSON & CO.INC.                          0.545623  0.268840  0.678152
# TIGER GLOBAL MANAGEMENT LLC                0.424423  0.164387  0.507414
# BERKSHIRE HATHAWAY INC                     1.000000  0.292033  0.688082
# Algo 1                                     0.292033  1.000000  0.288243
# Algo 2                                     0.688082  0.288243  1.000000
# S&P 500                                    0.751371  0.279494  0.858764
#
#                               S&P 500
# SOROS FUND MANAGEMENT LLC    0.837864
# PAULSON & CO.INC.            0.669732
# TIGER GLOBAL MANAGEMENT LLC  0.623946
# BERKSHIRE HATHAWAY INC       0.751371
# Algo 1                       0.279494
# Algo 2                       0.858764
# S&P 500                      1.000000

# %%
# Calculating beta for the Algo 1 portfolio vs. the S&P 500
covariance = all_returns_df['Algo 1'].rolling(window=60).cov(all_returns_df['S&P 500'].rolling(window=60))

variance = all_returns_df['S&P 500'].rolling(window=60).var()

algo_1_beta = covariance / variance

algo_1_beta.dropna(inplace=True)

algo_1_beta.plot(title='Algo 1 vs. S&P 500 Rolling 60-Day Beta', figsize=(20,10))

# %% [markdown]
# ### Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the `ewm` with a 21 day half-life.

# %%
# Calculating exponentially weighted moving averages
ewm = all_returns_df.ewm(halflife=21).mean()

# Printing sample
ewm.head()

# %% [markdown]
# ---

# %% [markdown]
# ## Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. (After all, if you could invest in one of two portfolios, each offered the same 10% return, yet one offered lower risk, you'd take that one, right?)
#
# Calculate and plot the annualized Sharpe ratios for all portfolios to determine which portfolio has the best performance

# %%
# Calculating annualized Sharpe ratios
sharpe_ratios = (all_returns_df.mean() * 252) / (all_returns_df.std() * np.sqrt(252))

sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# S&P 500                        0.648267
# dtype: float64

# %% [markdown]
#  plot() these sharpe ratios using a barplot.
#  On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales?

# %%
# Visualizing Sharpe ratios in a bar chart
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios",figsize=(20,10))

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Returns
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading the first stock
aapl_prices_csv = Path("Resources/aapl_prices.csv")

aapl_prices_df = pd.read_csv(aapl_prices_csv, 
                               index_col='Date', parse_dates=True, infer_datetime_format=True)

# Sorting by index
aapl_prices_df.sort_index(ascending=True, inplace=True)

# Printing sample
aapl_prices_df.head()
# Out:
#              Close
# Date
# 2015-01-04  124.25
# 2015-01-05  128.95
# 2015-01-06  130.54
# 2015-01-07  126.60
# 2015-01-09  107.72

# %%
# Read the second stock
fb_prices_csv = Path("Resources/fb_prices.csv")

fb_prices_df = pd.read_csv(fb_prices_csv, 
                               index_col='Date', parse_dates=True, infer_datetime_format=True)

# Sorting by index
fb_prices_df.sort_index(ascending=True, inplace=True)

# Printing sample
fb_prices_df.head()
# Out:
#             Close
# Date
# 2015-01-04  81.67
# 2015-01-05  78.99
# 2015-01-06  80.29
# 2015-01-07  86.91
# 2015-01-09  87.23

# %%
# Read the third stock
dis_prices_csv = Path("Resources/dis_prices.csv")

dis_prices_df = pd.read_csv(dis_prices_csv, 
                               index_col='Date', parse_dates=True, infer_datetime_format=True)

# Sorting by index
dis_prices_df.sort_index(ascending=True, inplace=True)

# Printing sample
dis_prices_df.head()
# Out:
#              Close
# Date
# 2015-01-04  105.44
# 2015-01-05  110.52
# 2015-01-06  110.96
# 2015-01-07  115.13
# 2015-01-09   99.51

# %%
# Concatenating all stocks into a single dataframe
my_port = pd.concat([aapl_prices_df,fb_prices_df,dis_prices_df], axis='columns', join='inner')

# Renaming columns
my_port.columns = ['AAPL','FB','DIS']

# Printing sample
my_port.head()
# Out:
#               AAPL     FB     DIS
# Date
# 2015-01-04  124.25  81.67  105.44
# 2015-01-05  128.95  78.99  110.52
# 2015-01-06  130.54  80.29  110.96
# 2015-01-07  126.60  86.91  115.13
# 2015-01-09  107.72  87.23   99.51

# %%
# Resetting the index
my_port.reset_index()
# Out:
#            Date    AAPL      FB     DIS
# 0    2015-01-04  124.25   81.67  105.44
# 1    2015-01-05  128.95   78.99  110.52
# 2    2015-01-06  130.54   80.29  110.96
# 3    2015-01-07  126.60   86.91  115.13
# 4    2015-01-09  107.72   87.23   99.51
# ...         ...     ...     ...     ...
# 1037 2019-11-03  178.90  172.07  114.75
# 1038 2019-11-04  198.95  177.51  116.60
# 1039 2019-12-02  170.89  165.04  109.20
# 1040 2019-12-03  180.91  171.92  114.73
# 1041 2019-12-04  198.87  179.10  130.06
#
# [1042 rows x 4 columns]

# %%
# Checking for null values
my_port.isnull().sum()
# Out:
# AAPL    0
# FB      0
# DIS     0
# dtype: int64

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Calculating weighted portfolio returns

# Assigning weights
weights = [1/3, 1/3, 1/3]

# Calculating daily returns
my_port_daily_returns = my_port.pct_change()

# Assigning portfolio weights and converting to dataframe
my_port_returns = my_port_daily_returns.dot(weights).to_frame()

# Dropping null values
my_port_returns.dropna(inplace=True)

# Renaming column
my_port_returns.columns = ['Portfolio Returns']

# Printing sample
my_port_returns.head()
# Out:
#             Portfolio Returns
# Date
# 2015-01-05           0.017730
# 2015-01-06           0.010923
# 2015-01-07           0.029950
# 2015-01-09          -0.093707
# 2015-01-10           0.030556

# %%
# Plotting cumulative returns for my portfolio
((my_port_returns + 1).cumprod() - 1).plot(title='3-Stock Portfolio Returns', figsize=(20,10))

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Concatenating my portolio returns to the main dataframe
all_port_returns = pd.concat([my_port_returns,all_returns_df], axis='columns', join='inner')

# %%
# Checking for null values
all_port_returns.isnull().sum()
# Out:
# Portfolio Returns              0
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# Algo 1                         0
# Algo 2                         0
# S&P 500                        0
# dtype: int64

# %%
# Renaming column for my portfolio returns
all_port_returns.rename(columns={'Portfolio Returns':'3-Stock Portfolio'},inplace=True)

# Confirming column name change
all_port_returns.head()
# Out:
#             3-Stock Portfolio  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03          -0.068057                  -0.001266           -0.004981
# 2015-03-06           0.028959                  -0.007905           -0.003574
# 2015-03-09          -0.096569                   0.000582            0.004225
# 2015-03-11           0.135697                   0.004012            0.005163
# 2015-03-12          -0.024724                   0.008265            0.010272
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
# 2015-03-11                     0.003312               -0.001147  0.002994
# 2015-03-12                     0.013117                0.010801 -0.002935
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-06 -0.011460 -0.014174
# 2015-03-09  0.001303  0.003944
# 2015-03-11  0.000605 -0.001918
# 2015-03-12  0.011667  0.012601

# %%
# Plotting cumulative returns of my portfolio vs. the S&P 500

((all_port_returns[['3-Stock Portfolio','S&P 500']] + 1).cumprod() - 1).plot(title='3-Stock Portfolio vs. S&P 500 Returns', figsize=(20,10))

# %% [markdown]
# ## Re-run the performance and risk analysis with your portfolio to see how it compares to the others

# %%
## Risk

# Box plotting all portfolios to show risk
all_port_returns.boxplot(figsize=(20,10))

# %%
# Calculating standard deviations for all portfolios and assigning to dataframe
all_std_df = all_port_returns.std().to_frame()

# Naming column
all_std_df.columns = ['Std. Dev.']

all_std_df
# Out:
#                              Std. Dev.
# 3-Stock Portfolio             0.039598
# SOROS FUND MANAGEMENT LLC     0.008055
# PAULSON & CO.INC.             0.007037
# TIGER GLOBAL MANAGEMENT LLC   0.011135
# BERKSHIRE HATHAWAY INC        0.013148
# Algo 1                        0.007625
# Algo 2                        0.008416
# S&P 500                       0.008633

# %%
# Calculating annualized standard deviation for all portfolios
all_volatility = all_port_returns.std() * np.sqrt(252)

all_volatility
# Out:
# 3-Stock Portfolio              0.628605
# SOROS FUND MANAGEMENT LLC      0.127868
# PAULSON & CO.INC.              0.111713
# TIGER GLOBAL MANAGEMENT LLC    0.176765
# BERKSHIRE HATHAWAY INC         0.208717
# Algo 1                         0.121042
# Algo 2                         0.133599
# S&P 500                        0.137051
# dtype: float64

# %%
## Rolling

# Plotting rolling 21-day standard deviation for my portfolio vs. the S&P 500
all_port_returns[['3-Stock Portfolio','S&P 500']].rolling(window=21).std().plot(
    title="Rolling 21-Day Std. Dev.", figsize=(20,10))

# %%
# Calculating beta of my portfolio vs. the S&P 500
my_port_covariance = all_port_returns['3-Stock Portfolio'].rolling(window=60).cov(all_port_returns['S&P 500'].rolling(window=60))

my_port_variance = all_port_returns['S&P 500'].rolling(window=60).var()

my_port_beta = my_port_covariance / my_port_variance

my_port_beta.plot(title='Beta vs. S&P 500',figsize=(20,10))

# %%
# Calculating annualized Sharpe ratios for all portfolios
all_sharpe_ratios = (all_port_returns.mean() * 252) / (all_port_returns.std() * np.sqrt(252))

all_sharpe_ratios
# Out:
# 3-Stock Portfolio              0.368635
# SOROS FUND MANAGEMENT LLC     -0.030371
# PAULSON & CO.INC.             -0.736208
# TIGER GLOBAL MANAGEMENT LLC   -0.024900
# BERKSHIRE HATHAWAY INC         0.166550
# Algo 1                         1.164675
# Algo 2                         0.195721
# S&P 500                        0.304753
# dtype: float64

# %%
# Visualizing the Sharpe ratios as a bar chart
all_sharpe_ratios.plot(kind="bar", title="Sharpe Ratios",figsize=(20,10))

# %% [markdown]
# ## Include correlation analysis to determine which stocks (if any) are correlated

# %%
# Calculating correlation within my portfolio
my_port.corr(method='pearson')
# Out:
#           AAPL        FB       DIS
# AAPL  1.000000  0.778899  0.480435
# FB    0.778899  1.000000  0.108233
# DIS   0.480435  0.108233  1.000000
